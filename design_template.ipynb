# %% [markdown]
# # Design Notebook: [Feature Name]
#
# **Date:** YYYY-MM-DD
# **Author:** [Your Name]
# **Status:** Draft | In Review | Approved | Implemented
#
# ---
#
# ## Quick Reference
# - **Problem:** [One sentence summary]
# - **Solution:** [One sentence summary]
# - **Impact:** [Files affected, breaking changes, etc.]
# - **Complexity:** Low | Medium | High
#
# ---
#
# **Instructions:** This is a template for design-first development. Complete ALL sections before writing any code. Update this notebook as you implement and discover new information.

# %% [markdown]
# # 1. Problem Statement
#
# ## What are we trying to solve?
#
# [Describe the problem in detail]
#
# ## User Requirements
#
# - Requirement 1: [Description]
# - Requirement 2: [Description]
# - Requirement 3: [Description]
#
# ## Pain Points
#
# - Pain point 1: [Current limitation]
# - Pain point 2: [Current limitation]
# - Pain point 3: [Current limitation]
#
# ## Success Criteria
#
# - [ ] Criterion 1
# - [ ] Criterion 2
# - [ ] Criterion 3

# %% [markdown]
# # 2. Current State Analysis
#
# ## What exists now?
#
# [Describe current implementation]
#
# ## Files/Modules Affected
#
# | File | Current State | Changes Needed |
# |------|--------------|----------------|
# | `file1.cpp` | Description | Changes |
# | `file2.py` | Description | Changes |
#
# ## Current Limitations
#
# 1. **Limitation 1:** [Description]
# 2. **Limitation 2:** [Description]
# 3. **Limitation 3:** [Description]
#
# ## Dependencies
#
# - Dependency 1: [Library/Module version]
# - Dependency 2: [Library/Module version]

# %% [markdown]
# # 3. Technical Design
#
# ## Architecture Overview
#
# ```
# [ASCII diagram or description of architecture]
#
# Component A --> Component B --> Component C
#      |              |              |
#      v              v              v
#   Data 1         Data 2         Data 3
# ```
#
# ## Data Structures
#
# ### Structure 1: [Name]
# ```cpp
# struct MyStructure {
#     int field1;
#     char field2[20];
#     float field3;
# };
# ```
#
# ### Structure 2: [Name]
# [Description]
#
# ## API/Interface Design
#
# ### Function 1
# ```cpp
# ReturnType functionName(ParamType param1, ParamType param2);
# ```
# - **Purpose:** [Description]
# - **Parameters:**
#   - `param1`: [Description]
#   - `param2`: [Description]
# - **Returns:** [Description]
# - **Side effects:** [Description]
#
# ## State Management
#
# - State variable 1: [Purpose and lifecycle]
# - State variable 2: [Purpose and lifecycle]
#
# ## Error Handling Strategy
#
# - Error case 1: [How to handle]
# - Error case 2: [How to handle]

# %%
# Pseudocode / Algorithm Design

def main_algorithm():
    """
    High-level pseudocode for the solution
    """
    # Step 1: Initialize
    initialize_components()
    
    # Step 2: Process
    for item in collection:
        process_item(item)
        
    # Step 3: Finalize
    cleanup_and_return()
    
# Add more detailed pseudocode as needed

# %% [markdown]
# # 4. Implementation Plan
#
# ## Task Breakdown
#
# ### Task 1: [Name]
# - **Description:** [What needs to be done]
# - **Files affected:** `file1.cpp`, `file2.h`
# - **Dependencies:** None | Requires Task X
# - **Complexity:** Low | Medium | High
# - **Estimated time:** [Time estimate]
# - **Status:** ⬜ Not Started | 🟡 In Progress | ✅ Complete
#
# ### Task 2: [Name]
# - **Description:** [What needs to be done]
# - **Files affected:** `file3.py`
# - **Dependencies:** Requires Task 1
# - **Complexity:** Low | Medium | High
# - **Estimated time:** [Time estimate]
# - **Status:** ⬜ Not Started
#
# ### Task 3: [Name]
# - **Description:** [What needs to be done]
# - **Files affected:** `file4.cpp`, `file5.h`
# - **Dependencies:** Requires Task 1, Task 2
# - **Complexity:** Low | Medium | High
# - **Estimated time:** [Time estimate]
# - **Status:** ⬜ Not Started
#
# ## Dependency Graph
#
# ```
# Task 1 (Independent)
#   |
#   ├─> Task 2
#   |     |
#   |     └─> Task 4
#   |
#   └─> Task 3
#         |
#         └─> Task 5
# ```
#
# ## Critical Path
#
# The critical path is: Task 1 → Task 2 → Task 4
#
# Total estimated time: [X hours/days]

# %% [markdown]
# # 5. Test Strategy
#
# ## Test Cases
#
# ### Test Case 1: [Name]
# - **Description:** [What is being tested]
# - **Input:** [Test input]
# - **Expected Output:** [Expected result]
# - **Actual Output:** [Fill in after testing]
# - **Status:** ⬜ Not Run | ✅ Passed | ❌ Failed
#
# ### Test Case 2: [Name]
# - **Description:** [What is being tested]
# - **Input:** [Test input]
# - **Expected Output:** [Expected result]
# - **Actual Output:** [Fill in after testing]
# - **Status:** ⬜ Not Run
#
# ### Test Case 3: [Name]
# - **Description:** [What is being tested]
# - **Input:** [Test input]
# - **Expected Output:** [Expected result]
# - **Actual Output:** [Fill in after testing]
# - **Status:** ⬜ Not Run
#
# ## Edge Cases
#
# 1. **Empty input:** [How to handle]
# 2. **Maximum values:** [How to handle]
# 3. **Null/undefined:** [How to handle]
# 4. **Concurrent access:** [How to handle]
#
# ## Integration Testing
#
# - Integration point 1: [How to test]
# - Integration point 2: [How to test]
#
# ## Performance Testing
#
# - Metric 1: [Target performance]
# - Metric 2: [Target performance]

# %%
# Test Helper Code (optional)

def run_test_case(test_name, input_data, expected_output):
    """
    Helper function to run test cases
    """
    print(f"Running: {test_name}")
    # Add test execution logic
    actual_output = None  # Replace with actual test
    
    if actual_output == expected_output:
        print(f"✅ {test_name} PASSED")
        return True
    else:
        print(f"❌ {test_name} FAILED")
        print(f"   Expected: {expected_output}")
        print(f"   Got: {actual_output}")
        return False

# Example usage:
# run_test_case("Test 1", input_data, expected_output)

# %% [markdown]
# # 6. Risk Assessment
#
# ## Potential Issues
#
# ### Risk 1: [Description]
# - **Likelihood:** Low | Medium | High
# - **Impact:** Low | Medium | High
# - **Mitigation:** [How to prevent or reduce]
# - **Contingency:** [What to do if it happens]
#
# ### Risk 2: [Description]
# - **Likelihood:** Low | Medium | High
# - **Impact:** Low | Medium | High
# - **Mitigation:** [How to prevent or reduce]
# - **Contingency:** [What to do if it happens]
#
# ### Risk 3: [Description]
# - **Likelihood:** Low | Medium | High
# - **Impact:** Low | Medium | High
# - **Mitigation:** [How to prevent or reduce]
# - **Contingency:** [What to do if it happens]
#
# ## Breaking Changes
#
# - Breaking change 1: [Description and impact]
# - Breaking change 2: [Description and impact]
#
# ## Backwards Compatibility
#
# - ✅ Fully backwards compatible
# - ⚠️ Requires migration: [Description]
# - ❌ Not backwards compatible: [Reason]
#
# ## Performance Impacts
#
# | Area | Current | Expected | Change |
# |------|---------|----------|--------|
# | Memory usage | X KB | Y KB | +Z KB |
# | Processing time | X ms | Y ms | +Z ms |
# | Network bandwidth | X KB/s | Y KB/s | +Z KB/s |
#
# ## Security Considerations
#
# - Security consideration 1: [Description]
# - Security consideration 2: [Description]

# %% [markdown]
# # 7. Implementation Log
#
# **Instructions:** Update this section as you implement. Document deviations from the plan, unexpected issues, and solutions.
#
# ## Implementation Progress
#
# | Date | Task | Status | Notes |
# |------|------|--------|-------|
# | YYYY-MM-DD | Task 1 | ✅ Complete | No issues |
# | YYYY-MM-DD | Task 2 | 🟡 In Progress | Found edge case... |
# | YYYY-MM-DD | Task 3 | ⬜ Not Started | Waiting for Task 2 |
#
# ## Deviations from Design
#
# ### Deviation 1: [Description]
# - **Original plan:** [What was planned]
# - **Actual implementation:** [What was done]
# - **Reason:** [Why the change was made]
# - **Impact:** [Consequences of the change]
#
# ### Deviation 2: [Description]
# - **Original plan:** [What was planned]
# - **Actual implementation:** [What was done]
# - **Reason:** [Why the change was made]
# - **Impact:** [Consequences of the change]
#
# ## Issues Encountered
#
# 1. **Issue 1:** [Description]
#    - **Solution:** [How it was resolved]
#
# 2. **Issue 2:** [Description]
#    - **Solution:** [How it was resolved]

# %% [markdown]
# # 8. Lessons Learned & Future Improvements
#
# ## What Went Well
#
# 1. [What worked well in the design/implementation]
# 2. [What worked well in the design/implementation]
# 3. [What worked well in the design/implementation]
#
# ## What Could Be Improved
#
# 1. [What could be better next time]
# 2. [What could be better next time]
# 3. [What could be better next time]
#
# ## Future Enhancements
#
# - Enhancement 1: [Description and benefit]
# - Enhancement 2: [Description and benefit]
# - Enhancement 3: [Description and benefit]
#
# ## Knowledge Gained
#
# - Learning 1: [New knowledge or insight]
# - Learning 2: [New knowledge or insight]
# - Learning 3: [New knowledge or insight]
#
# ---
#
# ## Final Checklist
#
# Before marking this design complete, ensure:
#
# - [ ] All sections are filled out
# - [ ] Technical design is detailed enough to implement
# - [ ] All tasks have complexity estimates
# - [ ] Test cases cover main functionality and edge cases
# - [ ] Risks are identified and mitigated
# - [ ] Implementation log is up to date
# - [ ] Code has been tested against test cases
# - [ ] Documentation is updated
# - [ ] Lessons learned are documented
#
# **Status:** ⬜ Draft | ⬜ Ready for Implementation | ⬜ Implementation Complete | ✅ Archived
